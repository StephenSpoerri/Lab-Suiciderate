# %%
import pandas as pd
import matplotlib

# %%
file = 'Suiciderates.csv'

# %%
import matplotlib.pyplot as plt

# %%
matplotlib.pyplot.xlabel("year")
matplotlib.pyplot.ylabel("percentage of deaths that are suicide")
x=[2017,2016,2015,2014,2013,2012,2011,2010,2009,2008,2007,2006,2005,2004,2003,2002,2001,2000,1999]
y=[1.68,1.64,1.63,1.63,1.58,1.6,1.57,1.55,1.51,1.46,1.43,1.37,1.33,1.35,1.28,1.3,1.27,1.22,1.22]
plt.bar(x,y)
plt.show()
